# %% [markdown]
# ## Домашнее задание 1. Markdown
# ## Номер задачи - заголовок 2
# ### Номер подзадачи - заголовок 3
# Предоставленные наборы данных оформляйте, как код
# ```
# a=int
# ```

# %% [markdown]
# ## Домашнее задание 2. Про фрукты и сложение из словаря
# ```
# def total_fruits(**kwargs):
#     new_sum = 0
#     for key, value in kwargs.items():
#         new_sum += value
#     print(new_sum)
# total_fruits(banana=5, orange=6,mango=8,apple=7,cocnut=3)
# ```

# %%
def total_fruits(**kwargs):
    new_sum = 0
    for key, value in kwargs.items():
        new_sum += value
    print(new_sum)

# %%
total_fruits(banana=5, orange=6,mango=8,apple=7,cocnut=3)
# Out:
# 29

# %% [markdown]
# ## Домашнее задание 3.
# ### Дан список с затратами на рекламу. Но в данных есть ошибки, некоторые затраты имеют отрицательную величину. Удалите такие значения из списка и посчитайте суммарные затраты
# [100, 125, -90, 345, 655, -1, 0, 200]
# #### Используйте list comprehensions

# %%
my_list = [100, 125, -90, 345, 655, -1, 0, 200]
new_list = [i for i in my_list if i > 0]
summon = 0
for item in range (0,len(new_list)):
    summon +=new_list[item]
print(summon)
# Out:
# 1425

# %% [markdown]
# ## Домашнее задание 4.
# ### Даны два списка.
# Дата покупки
# ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
# Суммы покупок по датам
# [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]
#
# #### 4.1 Найдите, какая выручка у компании в ноябре
# Используйте list comprehensions
# #### 4.2 Найдите выручку компании в зависимости от месяца
# Для этого напишите функцию, которая на вход принимает список с датами и список с выручкой, а на выходе словарь, где ключи - это месяцы, а значения - это выручка.
# Используйте аннотирование типов.

# %%
sale_list = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']

price_list = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]
vocab = [(a,b) for a in sale_list for b in price_list]
print(vocab)
# Out:
# [('2021-09-14', 1270), ('2021-09-14', 8413), ('2021-09-14', 9028), ('2021-09-14', 3703), ('2021-09-14', 5739), ('2021-09-14', 4095), ('2021-09-14', 295), ('2021-09-14', 4944), ('2021-09-14', 5723), ('2021-09-14', 3701), ('2021-09-14', 4471), ('2021-09-14', 651), ('2021-09-14', 7037), ('2021-09-14', 4274), ('2021-09-14', 6275), ('2021-09-14', 4988), ('2021-09-14', 6930), ('2021-09-14', 2971), ('2021-09-14', 6592), ('2021-09-14', 2004), ('2021-09-14', 2822), ('2021-09-14', 519), ('2021-09-14', 3406), ('2021-09-14', 2732), ('2021-09-14', 5015), ('2021-09-14', 2008), ('2021-09-14', 316), ('2021-09-14', 6333), ('2021-09-14', 5700), ('2021-09-14', 2887), ('2021-12-15', 1270), ('2021-12-15', 8413), ('2021-12-15', 9028), ('2021-12-15', 3703), ('2021-12-15', 5739), ('2021-12-15', 4095), ('2021-12-15', 295), ('2021-12-15', 4944), ('2021-12-15', 5723), ('2021-12-15', 3701), ('2021-12-15', 4471), ('2021-12-15', 651), ('2021-12-15', 7037), ('2021-12-15', 4274), ('2021-12-15', 6275), ('2021-12-15'
# ...

# %%
for item in sale_list:
    print(item)
# Out:
# 2021-09-14
# 2021-12-15
# 2021-09-08
# 2021-12-05
# 2021-10-09
# 2021-09-30
# 2021-12-22
# 2021-11-29
# 2021-12-24
# 2021-11-26
# 2021-10-27
# 2021-12-18
# 2021-11-09
# 2021-11-23
# 2021-09-27
# 2021-10-02
# 2021-12-27
# 2021-09-20
# 2021-12-13
# 2021-11-01
# 2021-11-09
# 2021-12-06
# 2021-12-08
# 2021-10-09
# 2021-10-31
# 2021-09-30
# 2021-11-09
# 2021-12-13
# 2021-10-26
# 2021-12-09

# %%
def calc_income_by_month(sale_list: list, price_list: list) -> dict:
    income_by_month = {}

    for i in range(len(sale_list)):
        month = sale_list[i].split('-')[1]
        if month in income_by_month.keys():
            income_by_month[month] += price_list[i]
        else:
            income_by_month[month] = price_list[i]

    return income_by_month

calc_income_by_month(sale_list, price_list)
# Out:
# {'09': 25647, '12': 45452, '10': 28645, '11': 25098}

# %% [markdown]
# #### Задание1. Соединить 2 словаря с анотированием

# %%
dict1 = {'One': 1, 'Two': 2, 'Three': 3}
dict2 = {'Four': 4, 'Five': 5, 'Six': 6}


def d1d2merge(a: dict, b:dict)-> dict: 
    dict1.update(dict2)
    return dict1


print(d1d2merge(dict1, dict2))
# Out:
# {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5, 'Six': 6}

# %%
dict1 = {'One': 1, 'Two': 2, 'Three': 3}
dict2 = {'Four': 4, 'Five': 5, 'Six': 6}
dict1.update(dict2)
dict1
# Out:
# {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5, 'Six': 6}

# %% [markdown]
# #### Задание2. Создание словаря из 2 списков

# %%
keys = ['One', 'Two', 'Three']
values = [1, 2, 3]

# %%
# %%time

new_dict = {keys[i]:values[i] for i in range (len(keys))}
print(new_dict)
# Out:
# {'One': 1, 'Two': 2, 'Three': 3}
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time
new_dict = dict()
for i in range (len(keys)):
    new_dict[keys[i]]=values[i]
print(new_dict)
# Out:
# {'One': 1, 'Two': 2, 'Three': 3}
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# #### Задание 3. Извлеките только два ключа name и age из представленного словаря (for;dict compreh)

# %%
client_dict = {
    "name": "John",
    "age": "25",
    "salary": "5000",
    "city":"Petersburg"
}

# %%
client_dict.items()
# Out:
# dict_items([('name', 'John'), ('age', '25'), ('salary', '5000'), ('city', 'Petersburg')])

# %%
client_dict.values()
# Out:
# dict_values(['John', '25', '5000', 'Petersburg'])

# %%
keys = ['name', 'age']

# %%
def new_dictionary(client_dict: dict, keys:list=['name', 'age'])-> dict:
    res = {}
    for k in keys:
        res.update({k:client_dict[k]})
    return res
new_dictionary(client_dict)
# Out:
# {'name': 'John', 'age': '25'}

# %%
{i:client_dict[i] for i in keys}
# Out:
# {'name': 'John', 'age': '25'}

# %% [markdown]
# #### Задание 4. Сгенерируйте случайные целые числа от 0 до 100 в количестве 5 штук с помощью модуля random

# %%
import random
my_list=[]
for i in range(5):
    my_list= random.randint(0,100)
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import random
my_list=[]
for i in range(5):
    my_list.append (random.randint(0,100))
print(my_list)
# Out:
# [30, 40, 8, 97, 50]

# %%
[random.randint(0,100)for i in range(5)]
# Out:
# [24, 93, 85, 28, 71]

# %% [markdown]
# #### Задание 5. Каритинка +таблица

# %% [markdown]
# <img src = 'https://catherineasquithgallery.com/uploads/posts/2021-02/1613449372_20-p-fon-dlya-prezentatsii-pro-vulkani-24.jpg'>

# %% [markdown]
# <table>
#     <tr>
#         <td></td>
#         <td>"1кол"</td>
#         <td>"2кол"</td>
#         <td>"3кол"</td>
#     </tr>
#     <tr>
#         <td></td>
#         <td>"Первая строчка 1кол"</td>
#         <td>"Первая строчка 2кол"</td>
#         <td>"Первая строчка 3кол"</td>
#     </tr>
#     <tr>
#         <td></td>
#         <td>"Вторая строчка 1кол"</td>
#         <td>"Вторая строчка 2кол"</td>
#         <td>"Вторая строчка 3кол"</td>
#     </tr>
#     <tr>
#         <td></td>
#         <td>"Третья строчка 1кол"</td>
#         <td>"Третья строчка 2кол"</td>
#         <td>"Третья строчка 3кол"</td>
#     </tr>
# </table>
